# %%
import sqlite3

# Create a SQLite database and establish a connection
conn = sqlite3.connect('jeopardy_questions.db')
cursor = conn.cursor()

# Create a table to store Jeopardy questions with a 'Points' column
cursor.execute('''CREATE TABLE JeopardyQuestions (
                    ID INTEGER PRIMARY KEY AUTOINCREMENT,
                    Category TEXT,
                    Question TEXT,
                    OptionA TEXT,
                    OptionB TEXT,
                    OptionC TEXT,
                    OptionD TEXT,
                    CorrectAnswer TEXT,
                    Points INTEGER
                )''')

# List of Jeopardy questions in the format: 
# (Category, Question, OptionA, OptionB, OptionC, OptionD, CorrectAnswer, Points)

jeopardy_questions = [
    # Category 1: Pattern Matching
    ("Pattern Matching", "Which symbol is used in regular expressions to match the beginning of a line?", "*", "^", "$", "%", "^", 100),
    ("Pattern Matching", "In regular expressions, what does the symbol '*' represent?", "A) Matches the end", "B) Matches zero or more occurrences of the preceding character", "C) Matches one or more occurrences of the preceding character", "D) Matches any single character", "B) Matches zero or more occurrences of the preceding character", 200),
    ("Pattern Matching", "Which command is used in Unix to perform pattern matching in file content?", "A) grep", "B) awk", "C) sed", "D) find", "A) grep", 300),
    ("Pattern Matching", "What regular expression character is used to match any single character?", "?", "*", ".", "+", "C) .", 400),
    ("Pattern Matching", "In regex, what does the character class [0-9] represent?", "A) Matches any digit from 0 to 9", "B) Matches any letter from a to z", "C) Matches any special character", "D) Matches any whitespace character", "A) Matches any digit from 0 to 9", 500),

    # Category 2: Unix
    ("Unix", "What command is used to display the current directory in Unix?", "A) ls", "B) pwd", "C) cd", "D) dir", "B) pwd", 100),
    ("Unix", "Which command is used to create a new directory in Unix?", "A) mkdir", "B) touch", "C) cp", "D) rm", "A) mkdir", 200),
    ("Unix", "Which command is used to list the contents of a directory in long format?", "A) ls -l", "B) dir -l", "C) ls -lt", "D) ls -a", "A) ls -l", 300),
    ("Unix", "What command is used to create a symbolic link in Unix/Linux?", "A) link", "B) shortcut", "C) ln -s", "D) symlink", "C) ln -s", 400),
    ("Unix", "What command is used to find and replace text in files?", "A) grep", "B) sed", "C) awk", "D) replace", "B) sed", 500),

    # Category 3: History of Computing
    ("History of Computing", "Which device is considered the first electronic general-purpose computer?", "A) ENIAC", "B) UNIVAC I", "C) Colossus", "D) Analytical Engine", "A) ENIAC", 100),
    ("History of Computing", "Who is often credited as the father of computer science and artificial intelligence?", "A) Alan Turing", "B) Charles Babbage", "C) Ada Lovelace", "D) John von Neumann", "A) Alan Turing", 200),
    ("History of Computing", "What year was the first computer virus discovered?", "A) 1986", "B) 1995", "C) 1971", "D) 2001", "C) 1971", 300),
    ("History of Computing", "Which programming language was developed by Dennis Ritchie in the early 1970s?", "A) Pascal", "B) Fortran", "C) COBOL", "D) C", "D) C", 400),
    ("History of Computing", "Who co-founded Apple Inc. alongside Steve Jobs?", "A) Bill Gates", "B) Steve Wozniak", "C) Larry Page", "D) Sergey Brin", "B) Steve Wozniak", 500),

    # Category 4: GNU Make
    ("GNU Make", "What does the GNU Make utility primarily manage?", "A) File permissions", "B) Software compilation", "C) Network configurations", "D) System security", "B) Software compilation", 100),
    ("GNU Make", "Which file is used as a configuration file for GNU Make?", "A) Makefile", "B) Config.make", "C) Compile.conf", "D) Build.txt", "A) Makefile", 200),
    ("GNU Make", "What is the purpose of 'make clean' in GNU Make?", "A) To delete the Makefile", "B) To clean the source code files", "C) To recompile the code", "D) To display help documentation", "B) To clean the source code files", 300),
    ("GNU Make", "What does := mean in makefile?", "A) simply expanded variables", "B) define", "C) equal", "D) export", "A) simply expanded variables", 400),
    ("GNU Make", "What does the '$@' symbol represent in a Makefile rule?", "A) Current directory", "B) First prerequisite", "C) Target of the rule", "D) All prerequisites", "C) Target of the rule", 500),

    # Category 5: Terminal
    ("Terminal", "Which command is used to list the contents of a directory in long format?", "A) ls -l", "B) dir -l", "C) ls -lt", "D) ls -a", "A) ls -l", 100),
    ("Terminal", "What command is used to navigate to the home directory in a Unix terminal?", "A) home", "B) cd ~", "C) move ~/", "D) cd /", "B) cd ~", 200),
    ("Terminal", "Which command is used to change the current directory?", "A) cd", "B) change", "C) mv", "D) switch", "A) cd", 300),
    ("Terminal", "What command is used to display the manual page of a specific command?", "A) help", "B) man", "C) info", "D) doc", "B) man", 400),
    ("Terminal", "Which command is used to compress files in Unix/Linux?", "A) zip", "B) compress", "C) tar", "D) gzip", "D) gzip", 500),

    # Category 6: SQL
    ("SQL", "Which SQL statement is used to retrieve data from a database?", "A) SELECT", "B) RETRIEVE", "C) FROM", "D) GETDATA", "A) SELECT", 100),
    ("SQL", "What does the acronym 'SQL' stand for?", "A) Structured Query Language", "B) System Query Logic", "C) Sequential Query Line", "D) Software Query Loop", "A) Structured Query Language", 200),
    ("SQL", "Which clause is used to filter records in a SQL query?", "A) WHERE", "B) HAVING", "C) FROM", "D) FILTER", "A) WHERE", 300),
    ("SQL", "What SQL function is used to count the number of rows in a table?", "A) COUNT()", "B) SUM()", "C) AVG()", "D) MAX()", "A) COUNT()", 400),
    ("SQL", "Which SQL command is used to add a new record to a table?", "A) INSERT INTO", "B) ADD RECORD", "C) MODIFY", "D) CREATE", "A) INSERT INTO", 500)
]


# Insert questions into the database
for question in jeopardy_questions:
    cursor.execute('''INSERT INTO JeopardyQuestions (Category, Question, OptionA, OptionB, OptionC, OptionD, CorrectAnswer, Points)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?)''', question)

# Commit changes and close the connection
conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd
# Connect to the SQLite database file
conn = sqlite3.connect('jeopardy_questions.db')

# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# Execute a SELECT query to fetch data
cursor.execute('SELECT * FROM JeopardyQuestions')

# # Fetch all rows from the query result
# rows = cursor.fetchall()

# # Iterate through the fetched rows
# for row in rows:
#     # Access data from each row
#     print(row)  # Example: Printing each row


# Fetch all rows from the query result
rows = cursor.fetchall()

# Get the column names from the cursor description
columns = [col[0] for col in cursor.description]

# Create a pandas DataFrame from the fetched rows and columns
df = pd.DataFrame(rows, columns=columns)

# Print the DataFrame or perform operations as needed
print(df)

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
#     ID              Category  \
# 0    1      Pattern Matching
# 1    2      Pattern Matching
# 2    3      Pattern Matching
# 3    4      Pattern Matching
# 4    5      Pattern Matching
# 5    6                  Unix
# 6    7                  Unix
# 7    8                  Unix
# 8    9                  Unix
# 9   10                  Unix
# 10  11  History of Computing
# 11  12  History of Computing
# 12  13  History of Computing
# 13  14  History of Computing
# 14  15  History of Computing
# 15  16              GNU Make
# 16  17              GNU Make
# 17  18              GNU Make
# 18  19              GNU Make
# 19  20              GNU Make
# 20  21              Terminal
# 21  22              Terminal
# 22  23              Terminal
# 23  24              Terminal
# 24  25              Terminal
# 25  26                   SQL
# 26  27                   SQL
# 27  28                   SQL
# 28  29                   SQL
# 29  30                   SQL
#
# ...

# %%
import sqlite3

# Connect to the SQLite database file
conn = sqlite3.connect('jeopardy_questions.db')

# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# # Example: Select all rows from a table named 'your_table_name'
# cursor.execute('SELECT * FROM Mytable')

# # Fetch the data
# data = cursor.fetchall()

# # Close the connection
# conn.close()

# # 'data' now contains the fetched data from the database
# print(data)
# Get the list of tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Display the list of tables
print("Tables in the database:")
print(tables)
for table in tables:
    print(table[0])

# Close the connection
conn.close()
# find all the tables...
# Out:
# Tables in the database:
# [('JeopardyQuestions',), ('sqlite_sequence',)]
# JeopardyQuestions
# sqlite_sequence

# %%
import sqlite3
import pandas as pd

# Connect to your SQLite database
conn = sqlite3.connect('jeopardy_questions.db')  # Replace 'your_database.db' with your database file path

# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# Execute a SELECT query on sqlite_sequence table
cursor.execute("SELECT * FROM sqlite_sequence")

# Fetch all rows from the sqlite_sequence table
rows = cursor.fetchall()

# Get column names from the cursor description
columns = [description[0] for description in cursor.description]

# Convert the rows to a Pandas DataFrame
df = pd.DataFrame(rows, columns=columns)

# Close the cursor and connection
cursor.close()
conn.close()

# Display the DataFrame
print(df)
# Out:
#                 name  seq
# 0  JeopardyQuestions   30
